# %%
import pandas as pd

# %%
iris = pd.read_csv('explanations_iris.csv')
wine = pd.read_csv('explanations_wine.csv')
breast_cancer = pd.read_csv('explanations_breast_cancer.csv')
digits = pd.read_csv('explanations_digits.csv')


data = pd.concat([iris, wine, breast_cancer, digits], ignore_index=True)

# %%
import json
def get_last(x):
  return json.loads(x)[-1]

data["len_relaxed_global"] = data["len_milp_relaxed"].apply(lambda x: get_last(x))
data["time_relaxed_global"] = data["time_milp_relaxed"].apply(lambda x: get_last(x))

# %%
desvio_padrao = (
    data.groupby(["dataset", "modelo"])[["len_milp", "len_relaxed_global", "time_milp", "time_relaxed_global"]]
    .std()
    .reset_index()
)
desvio_padrao
# Out:
#           dataset                      modelo  len_milp  len_relaxed_global  \
# 0   breast_cancer  model_1layers_20neurons.h5  3.571421            2.242473
# 1   breast_cancer  model_2layers_20neurons.h5  3.203470            0.000000
# 2   breast_cancer  model_3layers_20neurons.h5  2.112278            0.000000
# 3          digits  model_1layers_20neurons.h5  3.027467            0.000000
# 4          digits  model_2layers_20neurons.h5  3.235160            0.000000
# 5          digits  model_3layers_20neurons.h5  2.701851            0.000000
# 6            iris  model_1layers_20neurons.h5  0.504239            0.481335
# 7            iris  model_2layers_20neurons.h5  0.545549            0.500495
# 8            iris  model_3layers_20neurons.h5  0.521232            0.255242
# 9            wine  model_1layers_20neurons.h5  1.174060            0.627110
# 10           wine  model_2layers_20neurons.h5  1.329185            0.298511
# 11           wine  model_3layers_20neurons.h5  1.382923            0.000000
#
#     time_milp  time_relaxed_global
# 0    0.159814             0.052530
# 1    0.388237             0.063141
# 2    2.272917             0.040790
# 3    0.426832             0.140656
# 4    1.784925             0.041863
# 5   54.156833             0.065467
# 6    0.043329             0.017109
# 7    0.024172             0.020192
# 8    0.060224             0.013258
# 9    0.052315             0.035425
# 10   0.116748             0.036164
# 11   0.480932             0.108498

# %%
media = data.groupby(["dataset", "modelo"])[["len_milp", "len_relaxed_global", "time_milp", "time_relaxed_global"]].mean().reset_index()
media
# Out:
#           dataset                      modelo   len_milp  len_relaxed_global  \
# 0   breast_cancer  model_1layers_20neurons.h5  22.050000           29.040000
# 1   breast_cancer  model_2layers_20neurons.h5  22.020000           30.000000
# 2   breast_cancer  model_3layers_20neurons.h5  24.770000           30.000000
# 3          digits  model_1layers_20neurons.h5  43.810000           64.000000
# 4          digits  model_2layers_20neurons.h5  44.720000           64.000000
# 5          digits  model_3layers_20neurons.h5  45.400000           64.000000
# 6            iris  model_1layers_20neurons.h5   3.188119            3.643564
# 7            iris  model_2layers_20neurons.h5   2.772277            3.455446
# 8            iris  model_3layers_20neurons.h5   2.643564            3.930693
# 9            wine  model_1layers_20neurons.h5   9.039604           12.871287
# 10           wine  model_2layers_20neurons.h5   9.287129           12.970297
# 11           wine  model_3layers_20neurons.h5   9.495050           13.000000
#
#     time_milp  time_relaxed_global
# 0    0.387508             0.233614
# 1    0.790956             0.261473
# 2    2.884646             0.301615
# 3    1.482270             0.486738
# 4    4.809505             0.516628
# 5   79.660781             0.554853
# 6    0.046030             0.043579
# 7    0.072003             0.056957
# 8    0.150781             0.065586
# 9    0.144376             0.114709
# 10   0.324882             0.149581
# 11   0.873423             0.209317

# %% [markdown]
# todo: verificar uma forma de representar a redução da quantidade de features a medida que o relaxamento aumenta
