# %%
import pandas as pd

# %%
iris = pd.read_csv('explanations_iris.csv')
wine = pd.read_csv('explanations_wine.csv')
breast_cancer = pd.read_csv('explanations_breast_cancer.csv')
glass = pd.read_csv('explanations_glass.csv')
digits = pd.read_csv('explanations_digits.csv')


data = pd.concat([iris, wine, breast_cancer, digits, glass], ignore_index=True)

# %%
import json
def get_last(x):
  return json.loads(x)[-1]

data["len_relaxed_global"] = data["len_milp_relaxed"].apply(lambda x: get_last(x))
data["time_relaxed_global"] = data["time_milp_relaxed"].apply(lambda x: get_last(x))

# %%
desvio_padrao = (
    data.groupby(["dataset", "modelo"])[["len_milp", "len_relaxed_global", "time_milp", "time_relaxed_global"]]
    .std()
    .reset_index()
)
desvio_padrao
# Out:
#           dataset                      modelo  len_milp  len_relaxed_global  \
# 0   breast_cancer  model_1layers_20neurons.h5  3.571421            2.242473
# 1   breast_cancer  model_2layers_20neurons.h5  3.203470            0.000000
# 2   breast_cancer  model_3layers_20neurons.h5  2.112278            0.000000
# 3          digits  model_1layers_20neurons.h5  3.027467            0.000000
# 4          digits  model_2layers_20neurons.h5  3.235160            0.000000
# 5          digits  model_3layers_20neurons.h5  2.370453            0.000000
# 6           glass  model_1layers_10neurons.h5  0.918717            0.100000
# 7           glass  model_1layers_20neurons.h5  0.930461            0.200000
# 8           glass   model_1layers_5neurons.h5  1.132219            0.196946
# 9           glass  model_2layers_10neurons.h5  1.249808            0.100000
# 10          glass  model_2layers_20neurons.h5  1.262153            0.000000
# 11          glass   model_2layers_5neurons.h5  1.290055            0.000000
# 12          glass  model_3layers_10neurons.h5  0.903137            0.000000
# 13          glass  model_3layers_20neurons.h5  0.936089            0.000000
# 14          glass   model_3layers_5neurons.h5  0.858175            0.000000
# 15           iris  model_1layers_20neurons.h5  0.504239            0.481335
# 16           iris  model_2layers_20neurons.h5  0.545549            0.500495
# 17           iris  model_3layers_20neurons.h5  0.521232            0.255242
# 18           wine  model_1layers_20neurons.h5  1.174060            0.627110
# 19           wine  model_2layers_20neurons.h5  1.329185            0.298511
# 20           wine  model_3layers_20neurons.h5  1.382923            0.000000
#
#     time_milp  time_relaxed_global
# 0    0.159814             0.052530
# 1    0.388237             0.063141
# 2    2.272917             0.040790
# 3    0.426832             0.140656
# 4    1.784925             0.041863
# 5   47.694699             0.086607
# 6    0.035708             0.019364
# 7    0.020303             0.022823
# 8    0.029965             0.021892
# 9    0.038115             0.017436
# 10   0.056298             0.035995
# 11   0.033662             0.025254
# 12   0.046520             0.020811
# 13   0.104902             0.031937
# 14   0.031465             0.002084
# 15   0.043329             0.017109
# 16   0.024172             0.020192
# 17   0.060224             0.013258
# 18   0.052315             0.035425
# 19   0.116748             0.036164
# 20   0.480932             0.108498

# %%
media = data.groupby(["dataset", "modelo"])[["len_milp", "len_relaxed_global", "time_milp", "time_relaxed_global"]].mean().reset_index()
media
# Out:
#           dataset                      modelo   len_milp  len_relaxed_global  \
# 0   breast_cancer  model_1layers_20neurons.h5  22.050000           29.040000
# 1   breast_cancer  model_2layers_20neurons.h5  22.020000           30.000000
# 2   breast_cancer  model_3layers_20neurons.h5  24.770000           30.000000
# 3          digits  model_1layers_20neurons.h5  43.810000           64.000000
# 4          digits  model_2layers_20neurons.h5  44.720000           64.000000
# 5          digits  model_3layers_20neurons.h5  45.428571           64.000000
# 6           glass  model_1layers_10neurons.h5   7.620000            8.990000
# 7           glass  model_1layers_20neurons.h5   7.270000            8.980000
# 8           glass   model_1layers_5neurons.h5   7.030000            8.960000
# 9           glass  model_2layers_10neurons.h5   7.440000            8.990000
# 10          glass  model_2layers_20neurons.h5   6.770000            9.000000
# 11          glass   model_2layers_5neurons.h5   6.820000            9.000000
# 12          glass  model_3layers_10neurons.h5   7.650000            9.000000
# 13          glass  model_3layers_20neurons.h5   7.950000            9.000000
# 14          glass   model_3layers_5neurons.h5   7.470000            9.000000
# 15           iris  model_1layers_20neurons.h5   3.188119            3.643564
# 16           iris  model_2layers_20neurons.h5   2.772277            3.455446
# 17           iris  model_3layers_20neurons.h5   2.643564            3.930693
# 18           wine  model_1layers_20neurons.h5   9.039604           12.871287
# 19           wine  model_2layers_20neurons.h5   9.287129           12.970297
# 20           wine  model_3layers_20neurons.h5   9.495050           13.000000
#
#     time_milp  time_relaxed_global
# 0    0.387508             0.233614
# 1    0.790956             0.261473
# 2    2.884646             0.301615
# 3    1.482270             0.486738
# 4    4.809505             0.516628
# 5   76.960968             0.580802
# 6    0.068777             0.061939
# 7    0.074079             0.061452
# 8    0.065742             0.065551
# 9    0.096250             0.059650
# 10   0.168951             0.085213
# 11   0.078371             0.062543
# 12   0.139033             0.064267
# 13   0.278865             0.106358
# 14   0.072440             0.051179
# 15   0.046030             0.043579
# 16   0.072003             0.056957
# 17   0.150781             0.065586
# 18   0.144376             0.114709
# 19   0.324882             0.149581
# 20   0.873423             0.209317

# %%
media.query("dataset != 'glass'")
# Out:
#           dataset                      modelo   len_milp  len_relaxed_global  \
# 0   breast_cancer  model_1layers_20neurons.h5  22.050000           29.040000
# 1   breast_cancer  model_2layers_20neurons.h5  22.020000           30.000000
# 2   breast_cancer  model_3layers_20neurons.h5  24.770000           30.000000
# 3          digits  model_1layers_20neurons.h5  43.810000           64.000000
# 4          digits  model_2layers_20neurons.h5  44.720000           64.000000
# 5          digits  model_3layers_20neurons.h5  45.428571           64.000000
# 15           iris  model_1layers_20neurons.h5   3.188119            3.643564
# 16           iris  model_2layers_20neurons.h5   2.772277            3.455446
# 17           iris  model_3layers_20neurons.h5   2.643564            3.930693
# 18           wine  model_1layers_20neurons.h5   9.039604           12.871287
# 19           wine  model_2layers_20neurons.h5   9.287129           12.970297
# 20           wine  model_3layers_20neurons.h5   9.495050           13.000000
#
#     time_milp  time_relaxed_global
# 0    0.387508             0.233614
# 1    0.790956             0.261473
# 2    2.884646             0.301615
# 3    1.482270             0.486738
# 4    4.809505             0.516628
# 5   76.960968             0.580802
# 15   0.046030             0.043579
# 16   0.072003             0.056957
# 17   0.150781             0.065586
# 18   0.144376             0.114709
# 19   0.324882             0.149581
# 20   0.873423             0.209317

# %% [markdown]
# todo: verificar uma forma de representar a redução da quantidade de features a medida que o relaxamento aumenta
