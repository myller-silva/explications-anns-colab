# %%
import pandas as pd

# %%
iris = pd.read_csv('iris.csv')
wine = pd.read_csv('wine.csv')
breast_cancer = pd.read_csv('breast_cancer.csv')
glass = pd.read_csv('glass.csv')
digits = pd.read_csv('digits.csv')


data = pd.concat([iris, wine, breast_cancer, glass, digits], ignore_index=True)

# %%
import json
def get_last(x):
  return json.loads(x)[-1]

data["len_relaxed_global"] = data["len_milp_relaxed"].apply(lambda x: get_last(x))
data["time_relaxed_global"] = data["time_milp_relaxed"].apply(lambda x: get_last(x))

# %%
desvio_padrao = (
    data.groupby(["dataset", "modelo"])[["len_milp", "len_relaxed_global", "time_milp", "time_relaxed_global"]]
    .std()
    .reset_index()
)
desvio_padrao
# Out:
#           dataset                      modelo  len_milp  len_relaxed_global  \
# 0   breast_cancer  model_1layers_20neurons.h5  3.571421            2.242473
# 1   breast_cancer  model_2layers_20neurons.h5  3.203470            0.000000
# 2   breast_cancer  model_3layers_20neurons.h5  2.112278            0.000000
# 3          digits  model_1layers_20neurons.h5  3.027467            0.000000
# 4          digits  model_2layers_20neurons.h5  3.235160            0.000000
# 5          digits  model_3layers_20neurons.h5  3.119489            0.000000
# 6           glass  model_1layers_20neurons.h5  0.930461            0.200000
# 7           glass  model_2layers_20neurons.h5  1.262153            0.000000
# 8           glass  model_3layers_20neurons.h5  0.936089            0.000000
# 9            iris  model_1layers_20neurons.h5  0.506423            0.479372
# 10           iris  model_2layers_20neurons.h5  0.542720            0.500908
# 11           iris  model_3layers_20neurons.h5  0.519810            0.256432
# 12           wine  model_1layers_20neurons.h5  1.175293            0.630135
# 13           wine  model_2layers_20neurons.h5  1.329540            0.300000
# 14           wine  model_3layers_20neurons.h5  1.381662            0.000000
#
#      time_milp  time_relaxed_global
# 0     0.198670             0.053291
# 1     0.371528             0.035306
# 2     2.342899             0.074028
# 3     0.417327             0.068505
# 4     1.627694             0.044244
# 5   131.400339             1.341871
# 6     0.054633             0.046149
# 7     0.135903             0.048814
# 8     0.149811             0.062091
# 9     0.037493             0.010601
# 10    0.052968             0.054802
# 11    0.085790             0.049514
# 12    0.090048             0.039241
# 13    0.196432             0.101113
# 14    0.484451             0.078979

# %%
media = data.groupby(["dataset", "modelo"])[["len_milp", "len_relaxed_global", "time_milp", "time_relaxed_global"]].mean().reset_index()
media
# Out:
#           dataset                      modelo  len_milp  len_relaxed_global  \
# 0   breast_cancer  model_1layers_20neurons.h5     22.05               29.04
# 1   breast_cancer  model_2layers_20neurons.h5     22.02               30.00
# 2   breast_cancer  model_3layers_20neurons.h5     24.77               30.00
# 3          digits  model_1layers_20neurons.h5     43.81               64.00
# 4          digits  model_2layers_20neurons.h5     44.72               64.00
# 5          digits  model_3layers_20neurons.h5     46.19               64.00
# 6           glass  model_1layers_20neurons.h5      7.27                8.98
# 7           glass  model_2layers_20neurons.h5      6.77                9.00
# 8           glass  model_3layers_20neurons.h5      7.95                9.00
# 9            iris  model_1layers_20neurons.h5      3.19                3.65
# 10           iris  model_2layers_20neurons.h5      2.78                3.46
# 11           iris  model_3layers_20neurons.h5      2.65                3.93
# 12           wine  model_1layers_20neurons.h5      9.05               12.87
# 13           wine  model_2layers_20neurons.h5      9.30               12.97
# 14           wine  model_3layers_20neurons.h5      9.51               13.00
#
#     time_milp  time_relaxed_global
# 0    0.401388             0.224723
# 1    0.785395             0.244485
# 2    3.158405             0.320198
# 3    1.521639             0.464407
# 4    4.742540             0.495316
# 5   96.635993             0.720955
# 6    0.114606             0.094596
# 7    0.265564             0.129062
# 8    0.384952             0.147197
# 9    0.055623             0.049184
# 10   0.108514             0.084068
# 11   0.236068             0.100189
# 12   0.214451             0.141885
# 13   0.440400             0.220817
# 14   1.031463             0.237481

# %%
media.query("dataset != 'glass'")
# Out:
#           dataset                      modelo  len_milp  len_relaxed_global  \
# 0   breast_cancer  model_1layers_20neurons.h5     22.05               29.04
# 1   breast_cancer  model_2layers_20neurons.h5     22.02               30.00
# 2   breast_cancer  model_3layers_20neurons.h5     24.77               30.00
# 3          digits  model_1layers_20neurons.h5     43.81               64.00
# 4          digits  model_2layers_20neurons.h5     44.72               64.00
# 5          digits  model_3layers_20neurons.h5     46.19               64.00
# 9            iris  model_1layers_20neurons.h5      3.19                3.65
# 10           iris  model_2layers_20neurons.h5      2.78                3.46
# 11           iris  model_3layers_20neurons.h5      2.65                3.93
# 12           wine  model_1layers_20neurons.h5      9.05               12.87
# 13           wine  model_2layers_20neurons.h5      9.30               12.97
# 14           wine  model_3layers_20neurons.h5      9.51               13.00
#
#     time_milp  time_relaxed_global
# 0    0.401388             0.224723
# 1    0.785395             0.244485
# 2    3.158405             0.320198
# 3    1.521639             0.464407
# 4    4.742540             0.495316
# 5   96.635993             0.720955
# 9    0.055623             0.049184
# 10   0.108514             0.084068
# 11   0.236068             0.100189
# 12   0.214451             0.141885
# 13   0.440400             0.220817
# 14   1.031463             0.237481

# %% [markdown]
# todo: verificar uma forma de representar a redução da quantidade de features a medida que o relaxamento aumenta

# %%
# renomear os modelos para facilitar a visualização
data["modelo"] = data["modelo"].replace({
    "model_1layers_20neurons.h5": "1L20N",
    "model_2layers_20neurons.h5": "2L20N",
    "model_3layers_20neurons.h5": "3L20N",
    
})

grouped = data.groupby(["dataset", "modelo"])

# Calcular a média e o desvio padrão
mean_std = grouped[["len_relaxed_global", "time_relaxed_global"]].agg(['mean', 'std']).reset_index()

# Exibir como tabela
mean_std.columns = ['dataset', 'modelo', 'len_relaxed_global_mean', 'len_relaxed_global_std', 'time_relaxed_global_mean', 'time_relaxed_global_std']
mean_std["len_mean_std"] = mean_std.apply(lambda x: f'{x["len_relaxed_global_mean"]:.2f} ± {x["len_relaxed_global_std"]:.2f}', axis=1)
mean_std["time_mean_std"] = mean_std.apply(lambda x: f'{x["time_relaxed_global_mean"]:.2f} ± {x["time_relaxed_global_std"]:.2f}', axis=1)

# Exibir como tabela
print("Tabela 1: Média e desvio padrão do tamanho e tempo de execução das explicações relaxadas")
mean_std[["dataset", "modelo", "len_mean_std", "time_mean_std"]]
# Out:
# Tabela 1: Média e desvio padrão do tamanho e tempo de execução das explicações relaxadas
#           dataset modelo  len_mean_std time_mean_std
# 0   breast_cancer  1L20N  29.04 ± 2.24   0.22 ± 0.05
# 1   breast_cancer  2L20N  30.00 ± 0.00   0.24 ± 0.04
# 2   breast_cancer  3L20N  30.00 ± 0.00   0.32 ± 0.07
# 3          digits  1L20N  64.00 ± 0.00   0.46 ± 0.07
# 4          digits  2L20N  64.00 ± 0.00   0.50 ± 0.04
# 5          digits  3L20N  64.00 ± 0.00   0.72 ± 1.34
# 6           glass  1L20N   8.98 ± 0.20   0.09 ± 0.05
# 7           glass  2L20N   9.00 ± 0.00   0.13 ± 0.05
# 8           glass  3L20N   9.00 ± 0.00   0.15 ± 0.06
# 9            iris  1L20N   3.65 ± 0.48   0.05 ± 0.01
# 10           iris  2L20N   3.46 ± 0.50   0.08 ± 0.05
# 11           iris  3L20N   3.93 ± 0.26   0.10 ± 0.05
# 12           wine  1L20N  12.87 ± 0.63   0.14 ± 0.04
# 13           wine  2L20N  12.97 ± 0.30   0.22 ± 0.10
# 14           wine  3L20N  13.00 ± 0.00   0.24 ± 0.08
